# %% [markdown]
# # STEP 2 : image multiclass segmentation
# ![image.png](attachment:12835b73-26c3-4c11-b45b-948999f3dc01.png)
#
# **GOAL**: create masks with most important for animations features (face, body, hair+parts, eyes)
#
# ### imports

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in f:\anaconda3\lib\site-packages (1.12.1)
# Requirement already satisfied: typing_extensions in f:\anaconda3\lib\site-packages (from torch) (4.11.0)

# %%
pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\учеба\appdata\roaming\python\python311\site-packages (0.23.2)
# Requirement already satisfied: numpy>=1.23 in c:\users\учеба\appdata\roaming\python\python311\site-packages (from scikit-image) (1.24.4)
# Requirement already satisfied: scipy>=1.9 in c:\users\учеба\appdata\roaming\python\python311\site-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in f:\anaconda3\lib\site-packages (from scikit-image) (2.8.4)
# Requirement already satisfied: pillow>=9.1 in f:\anaconda3\lib\site-packages (from scikit-image) (10.2.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\учеба\appdata\roaming\python\python311\site-packages (from scikit-image) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\учеба\appdata\roaming\python\python311\site-packages (from scikit-image) (2024.5.3)
# Requirement already satisfied: packaging>=21 in f:\anaconda3\lib\site-packages (from scikit-image) (22.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\учеба\appdata\roaming\python\python311\site-packages (from scikit-image) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install imgaug --user
# Out:
# Requirement already satisfied: imgaug in c:\users\учеба\appdata\roaming\python\python311\site-packages (0.4.0)
# Requirement already satisfied: six in f:\anaconda3\lib\site-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\учеба\appdata\roaming\python\python311\site-packages (from imgaug) (1.24.4)
# Requirement already satisfied: scipy in c:\users\учеба\appdata\roaming\python\python311\site-packages (from imgaug) (1.10.1)
# Requirement already satisfied: Pillow in f:\anaconda3\lib\site-packages (from imgaug) (10.2.0)
# Requirement already satisfied: matplotlib in f:\anaconda3\lib\site-packages (from imgaug) (3.8.4)
# Requirement already satisfied: scikit-image>=0.14.2 in c:\users\учеба\appdata\roaming\python\python311\site-packages (from imgaug) (0.23.2)
# Requirement already satisfied: opencv-python in c:\users\учеба\appdata\roaming\python\python311\site-packages (from imgaug) (4.9.0.80)
# Requirement already satisfied: imageio in c:\users\учеба\appdata\roaming\python\python311\site-packages (from imgaug) (2.34.1)
# Requirement already satisfied: Shapely in f:\anaconda3\lib\site-packages (from imgaug) (2.0.4)
# Requirement already satisfied: networkx>=2.8 in f:\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug) (2.8.4)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\учеба\appdata\roaming\python\python311\site-packages (from scikit-image>=0.14.2->imgaug) (2024.5.3)
# Requirement already satisfied: packaging>=21 in f:\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug) (22.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\учеба\appdata\roaming\python\python311\site-packages (from scikit-image>=0.14.2->imgaug) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in f:\anaconda3\lib\site-packages (from matplotlib->imgaug) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in f:\anaconda3\lib\site-packages (from matplotlib->imgaug) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in f:\anaconda3\lib\site-packages (from matplotlib->imgaug) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\anaconda3\lib\site-packages (from matplotlib->imgaug) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\anaconda3\lib\site-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in f:\anaconda3\lib\site-packages (from matplotlib->imgaug) (2.8.2)

# %%
import os
import glob
import cv2
from PIL import Image
import numpy as np
import matplotlib as plt
import imgaug.augmenters as iaa

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
# Out:
# F:\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras import layers, Model
import tensorflow as tf
from keras.utils import normalize
from keras.optimizers import Adam
from keras.utils import to_categorical

# %%
# const
#BATCH_SIZE = 16
IMG_SHAPE  = (384, 256)
OUTPUT_SIZE = (384, 256)
CLASSES = 7
RANDOM_STATE = 42

# %% [markdown]
# ## Dataset
#
# My Dataset consists of 50 images, manualy labeled into 7 classes:
# 1. body (<span style="color:purple">purple</span>)
# 2. head (<span style="color:gold">yellow</span>)
# 3. hair_main (<span style="color:green">green</span>)
# 4. hair_bangs (<span style="color:orange">orange</span>)
# 5. hair_front (<span style="color:pink">pink</span>)
# 6. eyes (<span style="color:blue">blue</span>)
#
# I used [Supervisely](https://app.supervisely.com/projects/298168/datasets/940707) as a labeling tool.
#
# Ill convert my images to gray for easier computation

# %%
# images
train_images=[]

for directory_path in glob.glob(r'C:\Users\Nonamesoclever\Desktop\dataset 2024-05-04 11_49_21\img'):
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        img = cv2.imread(img_path, 0)       
        train_images.append(img)

# %%
# Convert list to array for machine learning processing
train_images=np.array(train_images)

# %%
# mask/label info as a list
train_masks = [] 

for directory_path in glob.glob(r'C:\Users\Nonamesoclever\Desktop\dataset 2024-05-04 11_49_21\masks_machine'):
    for mask_path in glob.glob(os.path.join(directory_path, "*.png")):
        mask = cv2.imread(mask_path, 0)       
        train_masks.append(mask)

# %%
train_masks = np.array(train_masks)

# %%
np.unique(train_masks)
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=uint8)

# %%
display(train_images.shape,
       train_masks.shape)
# Out:
# (50, 768, 512)
# (50, 768, 512)

# %%
import matplotlib.pyplot as plt
# Display the image in gray:
plt.imshow(train_images[13], cmap='gray')  # Use 'gray' colormap for grayscale images
plt.show()

# %%
plt.imshow(train_masks[13], cmap='gray')  # Use 'gray' colormap for grayscale images
plt.show()

# %% [markdown]
# My dataset is small, so I need to augment it:
#
# - Expand dataset to 2000 images
# - Resize them for easier computations

# %%
from skimage.transform import resize
import numpy as np
#import imageaug as iaa

# Assuming train_images and train_masks are defined elsewhere in your code
augmentation_pipeline = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.Flipud(0.5),
    iaa.Rotate((-10, 10)),
])

augmented_images = []
augmented_masks = []

random_indices = np.random.choice(range(len(train_images)), 2000, replace=True)

for idx in random_indices:
    image = train_images[idx]
    mask = train_masks[idx]
    
    # Since the mask is 2D, no transposition is needed
    aug_det = augmentation_pipeline.to_deterministic()
    image_aug = aug_det.augment_image(image)
    mask_aug = aug_det.augment_image(mask.astype(np.uint8))
        
    # Resize both the augmented image and its corresponding mask
    image_aug_resized = resize(image_aug, (384, 256))
    #mask_aug_resized = resize(mask_aug, (384, 256))
    # I need to keep my 7 classes in my mask:
    new_width, new_height = 256, 384
    pil_mask = Image.fromarray(mask_aug.astype(np.uint8))

    resized_pil_mask = pil_mask.resize((new_width, new_height))  # Replace new_width and new_height with desired dimensions

    resized_mask = np.array(resized_pil_mask)

    # Ensure the mask is in the correct format (e.g., uint8 for 8-bit images)
    resized_mask = resized_mask.astype(np.uint8)
    
    augmented_images.append(image_aug_resized)
    augmented_masks.append(resized_mask)

augmented_images = np.array(augmented_images)
augmented_masks = np.array(augmented_masks)

# %%
np.unique(augmented_masks)
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=uint8)

# %%
display(augmented_images.shape,
        augmented_masks.shape)
# Out:
# (2000, 384, 256)
# (2000, 384, 256)

# %% [markdown]
# Sanity-check:

# %%
import matplotlib.pyplot as plt
plt.imshow(augmented_images[1], cmap='gray')  # Use 'gray' colormap for grayscale images
plt.show()

# %%
plt.imshow(augmented_masks[1], cmap='gray')  # Use 'gray' colormap for grayscale images
plt.show()

# %%
labelencoder = LabelEncoder()
n, h, w = augmented_masks.shape
train_masks_reshaped = augmented_masks.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

np.unique(train_masks_encoded_original_shape)
# Out:
# F:\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
augmented_images = np.expand_dims(augmented_images, axis=3)
augmented_images = normalize(augmented_images, axis=1)

train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

# %%
display(augmented_images.shape,
       train_masks_input.shape)
# Out:
# (2000, 384, 256, 1)
# (2000, 384, 256, 1)

# %%
from sklearn.model_selection import train_test_split
X1, X_test, y1, y_test = train_test_split(augmented_images, train_masks_input, test_size = 0.10, random_state = RANDOM_STATE)

#Further split training data t a smaller subset for quick testing of models
X_train, X_do_not_use, y_train, y_do_not_use = train_test_split(X1, y1, test_size = 0.2, random_state = RANDOM_STATE)

print("Class values in the dataset are ... ", np.unique(y_train))  # 0 is the background/few unlabeled
# Out:
# Class values in the dataset are ...  [0 1 2 3 4 5 6]

# %%
display(X_train.shape,
       X_do_not_use.shape,
       X_test.shape)
# Out:
# (1440, 384, 256, 1)
# (360, 384, 256, 1)
# (200, 384, 256, 1)

# %%
from keras.utils import to_categorical
train_masks_cat = to_categorical(y_train, num_classes=CLASSES)
#y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))

test_masks_cat = to_categorical(y_test, num_classes=CLASSES)
#y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
display(train_masks_cat.shape,
       test_masks_cat.shape)
# Out:
# (1440, 384, 256, 7)
# (200, 384, 256, 7)

# %% [markdown]
# ---

# %% [markdown]
# My dataset is ready for U-Net model

# %% [markdown]
# ## Model: U-NET
# I`ll start with U-Net (64):
#
#
# ![image.png](attachment:d6828fde-9e68-40f0-b339-e7b7a87c2b96.png)

# %%
def multi_unet_model(n_classes=7, IMG_HEIGHT=384, IMG_WIDTH=256, IMG_CHANNELS=1):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    
    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
     
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
     
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
     
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    #Expansive path 
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
     
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
     
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
     
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
     
    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    
    
    #model.summary()
    
    return model

# %%
model = multi_unet_model()
# Out:
# WARNING:tensorflow:From F:\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:188: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
# for dice
def dice_coef(y_pred, y_true):
    y_pred = tf.unstack(y_pred, axis=3)
    y_true = tf.unstack(y_true, axis=3)
    dice_summ = 0

    for i, (a_y_pred, b_y_true) in enumerate(zip(y_pred, y_true)):
        dice_calculate = (2 * tf.math.reduce_sum(a_y_pred * b_y_true) + 1) /\
         (tf.math.reduce_sum(a_y_pred + b_y_true) + 1)

        dice_summ += dice_calculate
    avg_dice = dice_summ/CLASSES
    return avg_dice

def dice_loss(y_pred, y_true):
    d_loss = 1 - dice_coef(y_pred, y_true)
    return d_loss

def dice_bce_loss(y_pred, y_true):
    total_loss = 0.25 * dice_loss(y_pred, y_true) + tf.keras.losses.binary_crossentropy(y_pred, y_true)
    return total_loss

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#model.compile(optimizer='adam',
#              loss=[dice_bce_loss],
#              metrics=[dice_coef])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 384, 256, 1)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda (Lambda)               │ (None, 384, 256, 1)       │               0 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 384, 256, 16)      │             160 │ lambda[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 384, 256, 16)      │               0 │ conv2d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 384, 256, 16)      │           2,320 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 192, 128, 16)      │               0 │ conv2d_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 192, 128, 32)      │           4,640 │ max_pooling2d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 192, 128, 32)      │               0 │ conv2d_2[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 192, 128, 32)      │           9,248 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 96, 64, 32)        │               0 │ conv2d_3[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 96, 64, 64)        │          18,496 │ max_pooling2d_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 96, 64, 64)        │               0 │ conv2d_4[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 96, 64, 64)        │          36,928 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 48, 32, 64)        │               0 │ conv2d_5[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_6 (Conv2D)             │ (None, 48, 32, 128)       │          73,856 │ max_pooling2d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 48, 32, 128)       │               0 │ conv2d_6[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_7 (Conv2D)             │ (None, 48, 32, 128)       │         147,584 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 24, 16, 128)       │               0 │ conv2d_7[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_8 (Conv2D)             │ (None, 24, 16, 256)       │         295,168 │ max_pooling2d_3[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 24, 16, 256)       │               0 │ conv2d_8[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_9 (Conv2D)             │ (None, 24, 16, 256)       │         590,080 │ dropout_4[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose              │ (None, 48, 32, 128)       │         131,200 │ conv2d_9[0][0]             │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 48, 32, 256)       │               0 │ conv2d_transpose[0][0],    │
# │                               │                           │                 │ conv2d_7[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_10 (Conv2D)            │ (None, 48, 32, 128)       │         295,040 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 48, 32, 128)       │               0 │ conv2d_10[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_11 (Conv2D)            │ (None, 48, 32, 128)       │         147,584 │ dropout_5[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_1            │ (None, 96, 64, 64)        │          32,832 │ conv2d_11[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 96, 64, 128)       │               0 │ conv2d_transpose_1[0][0],  │
# │                               │                           │                 │ conv2d_5[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_12 (Conv2D)            │ (None, 96, 64, 64)        │          73,792 │ concatenate_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_6 (Dropout)           │ (None, 96, 64, 64)        │               0 │ conv2d_12[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_13 (Conv2D)            │ (None, 96, 64, 64)        │          36,928 │ dropout_6[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_2            │ (None, 192, 128, 32)      │           8,224 │ conv2d_13[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 192, 128, 64)      │               0 │ conv2d_transpose_2[0][0],  │
# │                               │                           │                 │ conv2d_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_14 (Conv2D)            │ (None, 192, 128, 32)      │          18,464 │ concatenate_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_7 (Dropout)           │ (None, 192, 128, 32)      │               0 │ conv2d_14[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_15 (Conv2D)            │ (None, 192, 128, 32)      │           9,248 │ dropout_7[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_3            │ (None, 384, 256, 16)      │           2,064 │ conv2d_15[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_3 (Concatenate)   │ (None, 384, 256, 32)      │               0 │ conv2d_transpose_3[0][0],  │
# │                               │                           │                 │ conv2d_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_16 (Conv2D)            │ (None, 384, 256, 16)      │           4,624 │ concatenate_3[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_8 (Dropout)           │ (None, 384, 256, 16)      │               0 │ conv2d_16[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_17 (Conv2D)            │ (None, 384, 256, 16)      │           2,320 │ dropout_8[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_18 (Conv2D)            │ (None, 384, 256, 7)       │             119 │ conv2d_17[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,940,919 (7.40 MB)
#  Trainable params: 1,940,919 (7.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# %%time
EPOCHS = 20
BATCH_S = 16


history = model.fit(X_train, train_masks_cat,
                    batch_size = BATCH_S, 
                    verbose=1, 
                    epochs=EPOCHS, 
                    validation_data=(X_test, test_masks_cat), 
                    shuffle=False)
# Out:
# Epoch 1/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.3636 - loss: 1.7247 - val_accuracy: 0.4283 - val_loss: 1.3613
# Epoch 2/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.5488 - loss: 1.2708 - val_accuracy: 0.6133 - val_loss: 1.1462
# Epoch 3/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.6002 - loss: 1.1553 - val_accuracy: 0.6177 - val_loss: 1.1136
# Epoch 4/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.6074 - loss: 1.1342 - val_accuracy: 0.6944 - val_loss: 0.9459
# Epoch 5/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.6138 - loss: 1.2449 - val_accuracy: 0.6939 - val_loss: 0.9507
# Epoch 6/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.6749 - loss: 0.9879 - val_accuracy: 0.7224 - val_loss: 0.8618
# Epoch 7/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.6976 - loss: 0.9071 - val_accuracy: 0.6944 - val_loss: 0.9320
# Epoch 8/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.7184 - loss: 0.8179 - val_accuracy: 0.7418 - val_loss: 0.7242
# Epoch 9/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.6670 - loss: 1.0146 - val_accuracy: 0.7314 - val_loss: 0.8110
# Epoch 10/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.7150 - loss: 0.8411 - val_accuracy: 0.7348 - val_loss: 0.7757
# Epoch 11/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.7386 - loss: 0.7613 - val_accuracy: 0.7641 - val_loss: 0.7112
# Epoch 12/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.7649 - loss: 0.6918 - val_accuracy: 0.7498 - val_loss: 0.7531
# Epoch 13/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.7849 - loss: 0.6214 - val_accuracy: 0.8090 - val_loss: 0.5686
# Epoch 14/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.8135 - loss: 0.5410 - val_accuracy: 0.8404 - val_loss: 0.4761
# Epoch 15/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.8250 - loss: 0.5147 - val_accuracy: 0.8415 - val_loss: 0.4747
# Epoch 16/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.8431 - loss: 0.4563 - val_accuracy: 0.8609 - val_loss: 0.4106
# Epoch 17/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.8673 - loss: 0.3838 - val_accuracy: 0.8392 - val_loss: 0.4947
# Epoch 18/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.8805 - loss: 0.3465 - val_accuracy: 0.8874 - val_loss: 0.3343
# Epoch 19/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.8935 - loss: 0.3104 - val_accuracy: 0.8767 - val_loss: 0.3839
# Epoch 20/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.9036 - loss: 0.2823 - val_accuracy: 0.9008 - val_loss: 0.3015
# CPU times: total: 10h 43min 32s
# Wall time: 42min 48s

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
_, acc = model.evaluate(X_test, test_masks_cat)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - accuracy: 0.9023 - loss: 0.2976
# Accuracy is =  90.08208513259888 %

# %%
prediction = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step

# %%
prediction[0].shape
# Out:
# (384, 256, 7)

# %%
def display_classes(mask):
    """
    Displays each class of the mask in separate subplots within a single figure.

    Parameters:
    - mask: A 3-dimensional NumPy array representing the mask.
    """
    num_classes = 7   
    list_of_classes=['background', 'body', 'face', 'back_hair', 'eyes', 'hair_front', 'bangs']
    fig, axs = plt.subplots(1, num_classes, figsize=(10, 20*num_classes))
    axs = axs.flatten()


    for i, ax in enumerate(axs):
        class_mask = mask[:,:,i]
        
        ax.imshow(class_mask, cmap='gray')
        ax.set_title(f'Class {list_of_classes[i]}')  
        ax.axis('off')  


    plt.tight_layout()

    plt.show()

# %%
# the image
plt.imshow(X_test[19], cmap='gray')
plt.show()

# %%
X_test[19].shape
# Out:
# (384, 256, 1)

# %%
display_classes(test_masks_cat[19])

# %%
display_classes(prediction[19])

# %% [markdown]
# ## Testing
#
# I`ll final test my model on original dataset (that I augmented later):

# %%
test_image_final = []

# %%
for i in range(0, 40):
    test_image = resize(train_images[i], (384, 256))
    test_image_final.append(test_image)

# %%
test_image_final=np.array(test_image_final)

# %%
test_image_final.shape
# Out:
# (40, 384, 256)

# %%
test_image_final = np.expand_dims(test_image_final, axis=3)
test_image_final = normalize(test_image_final, axis=1)

# %%
test_image_final.shape
# Out:
# (40, 384, 256, 1)

# %%
prediction = model.predict(test_image_final)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step

# %%
plt.imshow(test_image_final[10], cmap='gray')
plt.show()

# %%
display_classes(prediction[10])

# %%
from matplotlib.colors import ListedColormap
import matplotlib.colors as mcolors

transparent_black = mcolors.colorConverter.to_rgba('black', alpha=0)
colormap = ListedColormap([transparent_black, 'red'])

def color_change(i):
    list_of_colors=['black', 'purple', 'yellow', 'green', 'blue', 'pink', 'orange']
    return ListedColormap([transparent_black, list_of_colors[i]])

plt.imshow(test_image_final[10], cmap='gray')


for i in range(0, 7):    
    plt.imshow(prediction[10][:,:,i], cmap=color_change(i), alpha=0.5)

plt.imshow(test_image_final[10], cmap='gray', alpha=0.2)
plt.axis('off')

# Show the plot
plt.show()

# %% [markdown]
# ![image.png](attachment:eb87a857-5bfa-432c-9eb6-3376f58abedc.png)
